# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\bwara\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\bwara\anaconda3\envs\pyvizenv\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
# Read your api key environment variable
load_dotenv('C:/Users/bwara/Jupyter-workspace/.env')
# Out:
# True

# %%
# Create a newsapi client
from newsapi.newsapi_client import NewsApiClient
newsapi = NewsApiClient(api_key=os.environ["NEWS_API"])

# %%
# Fetch the Bitcoin news articles
Bitcoin_headlines = newsapi.get_everything(q="ethereum", language="en")
Bitcoin_headlines["articles"][0]
# Out:
# {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#  'author': 'David Riggs',
#  'title': 'Radical Ethereum entrepreneurs are redefining what ‘rape kit’ means',
#  'description': 'Their investors call them disruptive innovators and detractors. Some call them “dirty scammers.” But the Leda Health co-founders think of themselves as advocates for sexual assault survivors.',
#  'url': 'http://techcrunch.com/2021/05/04/radical-ethereum-entrepreneurs-are-redefining-what-rape-kit-means/',
#  'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/05/created-for-survivors.jpg?w=710',
#  'publishedAt': '2021-05-04T14:30:39Z',
#  'content': 'Their investors call them disruptive innovators. Detractors like North Carolina Attorney General Josh Stein call them dirty scammers. But Leda Health co-founders Madison Campbell and Liesel Vaidya th… [+8679 chars]'}

# %%
# Fetch the Ethereum news articles
Ethereum_headlines = newsapi.get_everything(q="ethereum", language="en")
Ethereum_headlines["articles"][0]
# Out:
# {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#  'author': 'David Riggs',
#  'title': 'Radical Ethereum entrepreneurs are redefining what ‘rape kit’ means',
#  'description': 'Their investors call them disruptive innovators and detractors. Some call them “dirty scammers.” But the Leda Health co-founders think of themselves as advocates for sexual assault survivors.',
#  'url': 'http://techcrunch.com/2021/05/04/radical-ethereum-entrepreneurs-are-redefining-what-rape-kit-means/',
#  'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/05/created-for-survivors.jpg?w=710',
#  'publishedAt': '2021-05-04T14:30:39Z',
#  'content': 'Their investors call them disruptive innovators. Detractors like North Carolina Attorney General Josh Stein call them dirty scammers. But Leda Health co-founders Madison Campbell and Liesel Vaidya th… [+8679 chars]'}

# %%
# Create the Bitcoin sentiment scores DataFrame
bitcoin_sentiments = []

for article in Bitcoin_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        bitcoin_sentiments.append({
            "text": text,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
bitcoin_df = pd.DataFrame(bitcoin_sentiments)

# Reorder DataFrame columns
cols = ["text", "compound", "positive", "negative", "neutral"]
bitcoin_df = bitcoin_df[cols]

bitcoin_df.head()
# Out:
#                                                 text  compound  positive  \
# 0  Their investors call them disruptive innovator...   -0.4019     0.072
# 1  Cryptocurrency continues to gain mainstream ac...    0.7506     0.171
# 2  Venmo is jumping aboard the cryptocurrency ban...    0.0258     0.034
# 3  New York (CNN Business)Bitcoin prices continue...    0.0000     0.000
# 4  The creators behind CryptoPunks, one of the mo...    0.4754     0.091
#
#    negative  neutral
# 0      0.15    0.778
# 1      0.00    0.829
# 2      0.00    0.966
# 3      0.00    1.000
# 4      0.00    0.909

# %%
# Create the Ethereum sentiment scores DataFrame
ethereum_sentiments = []

for article in Ethereum_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ethereum_sentiments.append({
            "text": text,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
ethereum_df = pd.DataFrame(ethereum_sentiments)

# Reorder DataFrame columns
cols = ["text", "compound", "positive", "negative", "neutral"]
ethereum_df = ethereum_df[cols]

ethereum_df.head()
# Out:
#                                                 text  compound  positive  \
# 0  Their investors call them disruptive innovator...   -0.4019     0.072
# 1  Cryptocurrency continues to gain mainstream ac...    0.7506     0.171
# 2  Venmo is jumping aboard the cryptocurrency ban...    0.0258     0.034
# 3  New York (CNN Business)Bitcoin prices continue...    0.0000     0.000
# 4  The creators behind CryptoPunks, one of the mo...    0.4754     0.091
#
#    negative  neutral
# 0      0.15    0.778
# 1      0.00    0.829
# 2      0.00    0.966
# 3      0.00    1.000
# 4      0.00    0.909

# %%
# Describe the Bitcoin Sentiment
bitcoin_df.describe()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-3aca8a8b8a98> in <module>
#       1 # Describe the Bitcoin Sentiment
# ----> 2 bitcoin_df.describe()
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\generic.py in describe(self, percentiles, include, exclude)
#    9791         elif (include is None) and (exclude is None):
#    9792             # when some numerics are found, keep only numerics
# -> 9793             data = self.select_dtypes(include=[np.number])
#    9794             if len(data.columns) == 0:
#    9795                 data = self
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\frame.py in select_dtypes(self, include, exclude)
#    3324         # the "union" of the logic of case 1 and case 2:
#    3325         # we get the included and excluded, and return their logical and
# -> 3326         include_these = Series(not bool(include), index=self.columns)
#    3327         exclude_these = Series(not bool(exclude), index=self.columns)
#    3328
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     260             else:
#     261                 data = sanitize_array(data, index, dtype, copy,
# --> 262                                       raise_cast_failure=True)
#     263
#     264                 data = SingleBlockManager(data, index, fastpath=True)
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\internals\construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     640
#     641             subarr = construct_1d_arraylike_from_scalar(
# --> 642                 value, len(index), dtype)
#     643
#     644         else:
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\dtypes\cast.py in construct_1d_arraylike_from_scalar(value, length, dtype)
#    1185                 value = to_str(value)
#    1186
# -> 1187         subarr = np.empty(length, dtype=dtype)
#    1188         subarr.fill(value)
#    1189
#
# TypeError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type

# %%
# Describe the Ethereum Sentiment
ethereum_df.describe()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-0aef0beecdea> in <module>
#       1 # Describe the Ethereum Sentiment
# ----> 2 ethereum_df.describe()
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\generic.py in describe(self, percentiles, include, exclude)
#    9791         elif (include is None) and (exclude is None):
#    9792             # when some numerics are found, keep only numerics
# -> 9793             data = self.select_dtypes(include=[np.number])
#    9794             if len(data.columns) == 0:
#    9795                 data = self
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\frame.py in select_dtypes(self, include, exclude)
#    3324         # the "union" of the logic of case 1 and case 2:
#    3325         # we get the included and excluded, and return their logical and
# -> 3326         include_these = Series(not bool(include), index=self.columns)
#    3327         exclude_these = Series(not bool(exclude), index=self.columns)
#    3328
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     260             else:
#     261                 data = sanitize_array(data, index, dtype, copy,
# --> 262                                       raise_cast_failure=True)
#     263
#     264                 data = SingleBlockManager(data, index, fastpath=True)
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\internals\construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     640
#     641             subarr = construct_1d_arraylike_from_scalar(
# --> 642                 value, len(index), dtype)
#     643
#     644         else:
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\dtypes\cast.py in construct_1d_arraylike_from_scalar(value, length, dtype)
#    1185                 value = to_str(value)
#    1186
# -> 1187         subarr = np.empty(length, dtype=dtype)
#    1188         subarr.fill(value)
#    1189
#
# TypeError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A:
#
# Q: Which coin had the highest compound score?
#
# A:
#
# Q. Which coin had the highest positive score?
#
# A:

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
print(stopwords.words("english"))

# Expand the default stopwords list if necessary
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    sw = set(stopwords.words('english'))
    
    # Remove the punctuation from text
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text)

    # Create a tokenized list of the words
    words = word_tokenize(re_clean)

    # Lemmatize words into root words
    lemmatizer = WordNetLemmatizer()
    lem = [lemmatizer.lemmatize(word) for word in words]

    # Convert the words to lowercase
    token = [word.lower() for word in lem if word.lower() not in sw]
    
    # Remove the stop words
    
    
    return token

# %%
# Create a new tokens column for Bitcoin
bitcoin_df['tokens'] = bitcoin_df['text'].apply(tokenizer)
bitcoin_df.head()
# Out:
#                                                 text  compound  positive  \
# 0  Their investors call them disruptive innovator...   -0.4019     0.072
# 1  Cryptocurrency continues to gain mainstream ac...    0.7506     0.171
# 2  Venmo is jumping aboard the cryptocurrency ban...    0.0258     0.034
# 3  New York (CNN Business)Bitcoin prices continue...    0.0000     0.000
# 4  The creators behind CryptoPunks, one of the mo...    0.4754     0.091
#
#    negative  neutral                                             tokens
# 0      0.15    0.778  [investor, call, disruptive, innovator, detrac...
# 1      0.00    0.829  [cryptocurrency, continues, gain, mainstream, ...
# 2      0.00    0.966  [venmo, jumping, aboard, cryptocurrency, bandw...
# 3      0.00    1.000  [new, york, cnn, businessbitcoin, price, conti...
# 4      0.00    0.909  [creator, behind, cryptopunks, one, popular, n...

# %%
# Create a new tokens column for Ethereum
ethereum_df['tokens'] = ethereum_df['text'].apply(tokenizer)
ethereum_df.head()
# Out:
#                                                 text  compound  positive  \
# 0  Their investors call them disruptive innovator...   -0.4019     0.072
# 1  Cryptocurrency continues to gain mainstream ac...    0.7506     0.171
# 2  Venmo is jumping aboard the cryptocurrency ban...    0.0258     0.034
# 3  New York (CNN Business)Bitcoin prices continue...    0.0000     0.000
# 4  The creators behind CryptoPunks, one of the mo...    0.4754     0.091
#
#    negative  neutral                                             tokens
# 0      0.15    0.778  [investor, call, disruptive, innovator, detrac...
# 1      0.00    0.829  [cryptocurrency, continues, gain, mainstream, ...
# 2      0.00    0.966  [venmo, jumping, aboard, cryptocurrency, bandw...
# 3      0.00    1.000  [new, york, cnn, businessbitcoin, price, conti...
# 4      0.00    0.909  [creator, behind, cryptopunks, one, popular, n...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
bitcoin_words = tokenizer(''.join(str(bitcoin_df['text'].tolist())))
bitcoin_counts = Counter(ngrams(bitcoin_words, n=2))
print(dict(bitcoin_counts))
# Out:
# {('investor', 'call'): 1, ('call', 'disruptive'): 1, ('disruptive', 'innovator'): 1, ('innovator', 'detractors'): 1, ('detractors', 'like'): 1, ('like', 'north'): 1, ('north', 'carolina'): 1, ('carolina', 'attorney'): 1, ('attorney', 'general'): 1, ('general', 'josh'): 1, ('josh', 'stein'): 1, ('stein', 'call'): 1, ('call', 'dirty'): 1, ('dirty', 'scammer'): 1, ('scammer', 'leda'): 1, ('leda', 'health'): 1, ('health', 'cofounder'): 1, ('cofounder', 'madison'): 1, ('madison', 'campbell'): 1, ('campbell', 'liesel'): 1, ('liesel', 'vaidya'): 1, ('vaidya', 'th'): 1, ('th', 'char'): 3, ('char', 'cryptocurrency'): 1, ('cryptocurrency', 'continues'): 1, ('continues', 'gain'): 1, ('gain', 'mainstream'): 1, ('mainstream', 'acceptance'): 1, ('acceptance', 'paypal'): 1, ('paypal', 'announced'): 1, ('announced', 'added'): 1, ('added', 'bitcoin'): 1, ('bitcoin', 'ethereum'): 3, ('ethereum', 'bitcoin'): 1, ('bitcoin', 'cash'): 1, ('cash', 'litecoin'): 1, ('litecoin', 'venmo'): 1, ('venmo', 'app'): 1, ('app', 'user'): 1, ('user', 'base'): 1, ('base', 'million'): 1, ('million', 'mo'): 1, ('mo', 'char'): 1, ('char', 'venmo'): 1, ('venmo', 'jumping'): 1, ('jumping', 'aboard'): 1, ('aboard', 'cryptocurrency'): 1, ('cryptocurrency', 'bandwagonxarnthe'): 1, ('bandwagonxarnthe', 'social'): 1, ('social', 'payment'): 1, ('payment', 'service'): 1, ('service', 'announced'): 1, ('announced', 'tuesday'): 1, ('tuesday', 'customer'): 1, ('customer', 'buy'): 1, ('buy', 'hold'): 1, ('hold', 'sell'): 1, ('sell', 'cryptocurrencies'): 1, ('cryptocurrencies', 'within'): 1, ('within', 'venmo'): 1, ('venmo', 'appxarnfour'): 1, ('appxarnfour', 'cr'): 1, ('cr', 'char'): 1, ('char', 'new'): 2, ('new', 'york'): 2, ('york', 'cnn'): 1, ('cnn', 'businessbitcoin'): 1, ('businessbitcoin', 'price'): 1, ('price', 'continued'): 1, ('continued', 'rebound'): 1, ('rebound', 'saturday'): 1, ('saturday', 'rising'): 1, ('rising', 'nearly'): 1, ('nearly', 'world'): 1, ('world', 'largest'): 1, ('largest', 'cryptocurrency'): 1, ('cryptocurrency', 'ha'): 1, ('ha', 'overshadowed'): 1, ('overshadowed', 'lately'): 1, ('lately', 'younger'): 1, ('younger', 'sibling'): 1, ('sibling', 'char'): 1, ('char', 'creator'): 1, ('creator', 'behind'): 1, ('behind', 'cryptopunks'): 1, ('cryptopunks', 'one'): 1, ('one', 'popular'): 1, ('popular', 'nft'): 1, ('nft', 'project'): 1, ('project', 'web'): 1, ('web', 'revealed'): 1, ('revealed', 'latest'): 1, ('latest', 'project'): 1, ('project', 'called'): 1, ('called', 'meebits'): 1, ('meebits', 'project'): 1, ('project', 'boast'): 1, ('boast', 'procedurally'): 1, ('procedurally', 'generated'): 1, ('generated', 'character'): 1, ('character', 'tha'): 1, ('tha', 'char'): 1, ('char', 'consensys'): 1, ('consensys', 'key'): 1, ('key', 'player'): 1, ('player', 'crypto'): 1, ('crypto', 'major'): 1, ('major', 'proponent'): 1, ('proponent', 'ethereum'): 1, ('ethereum', 'blockchain'): 1, ('blockchain', 'ha'): 1, ('ha', 'raised'): 1, ('raised', 'axa'): 1, ('axa', 'million'): 1, ('million', 'funding'): 1, ('funding', 'round'): 1, ('round', 'fromxajp'): 1, ('fromxajp', 'morgan'): 1, ('morgan', 'mastercard'): 1, ('mastercard', 'ubs'): 1, ('ubs', 'ag'): 1, ('ag', 'well'): 1, ('well', 'major'): 1, ('major', 'blockchain'): 1, ('blockchain', 'compan'): 1, ('compan', 'char'): 1, ('char', 'reuters'): 4, ('reuters', 'staffrnfile'): 2, ('staffrnfile', 'photo'): 2, ('photo', 'representation'): 2, ('representation', 'virtual'): 4, ('virtual', 'currency'): 4, ('currency', 'ethereum'): 4, ('ethereum', 'seen'): 4, ('seen', 'front'): 4, ('front', 'stock'): 4, ('stock', 'graph'): 4, ('graph', 'illustration'): 4, ('illustration', 'taken'): 4, ('taken', 'february'): 4, ('february', 'reutersdado'): 4, ('reutersdado', 'ruvicillustrationrnsingapore'): 2, ('ruvicillustrationrnsingapore', 'char'): 2, ('char', 'representation'): 2, ('reutersdado', 'ruvicillustrationcryptocurrency'): 2, ('ruvicillustrationcryptocurrency', 'ether'): 2, ('ether', 'hit'): 3, ('hit', 'record'): 3, ('record', 'high') ...

# %%
# Generate the Ethereum N-grams where N=2
ethereum_words = tokenizer(''.join(str(ethereum_df['text'].tolist())))
ethereum_counts = Counter(ngrams(ethereum_words, n=2))
print(dict(ethereum_counts))
# Out:
# {('investor', 'call'): 1, ('call', 'disruptive'): 1, ('disruptive', 'innovator'): 1, ('innovator', 'detractors'): 1, ('detractors', 'like'): 1, ('like', 'north'): 1, ('north', 'carolina'): 1, ('carolina', 'attorney'): 1, ('attorney', 'general'): 1, ('general', 'josh'): 1, ('josh', 'stein'): 1, ('stein', 'call'): 1, ('call', 'dirty'): 1, ('dirty', 'scammer'): 1, ('scammer', 'leda'): 1, ('leda', 'health'): 1, ('health', 'cofounder'): 1, ('cofounder', 'madison'): 1, ('madison', 'campbell'): 1, ('campbell', 'liesel'): 1, ('liesel', 'vaidya'): 1, ('vaidya', 'th'): 1, ('th', 'char'): 3, ('char', 'cryptocurrency'): 1, ('cryptocurrency', 'continues'): 1, ('continues', 'gain'): 1, ('gain', 'mainstream'): 1, ('mainstream', 'acceptance'): 1, ('acceptance', 'paypal'): 1, ('paypal', 'announced'): 1, ('announced', 'added'): 1, ('added', 'bitcoin'): 1, ('bitcoin', 'ethereum'): 3, ('ethereum', 'bitcoin'): 1, ('bitcoin', 'cash'): 1, ('cash', 'litecoin'): 1, ('litecoin', 'venmo'): 1, ('venmo', 'app'): 1, ('app', 'user'): 1, ('user', 'base'): 1, ('base', 'million'): 1, ('million', 'mo'): 1, ('mo', 'char'): 1, ('char', 'venmo'): 1, ('venmo', 'jumping'): 1, ('jumping', 'aboard'): 1, ('aboard', 'cryptocurrency'): 1, ('cryptocurrency', 'bandwagonxarnthe'): 1, ('bandwagonxarnthe', 'social'): 1, ('social', 'payment'): 1, ('payment', 'service'): 1, ('service', 'announced'): 1, ('announced', 'tuesday'): 1, ('tuesday', 'customer'): 1, ('customer', 'buy'): 1, ('buy', 'hold'): 1, ('hold', 'sell'): 1, ('sell', 'cryptocurrencies'): 1, ('cryptocurrencies', 'within'): 1, ('within', 'venmo'): 1, ('venmo', 'appxarnfour'): 1, ('appxarnfour', 'cr'): 1, ('cr', 'char'): 1, ('char', 'new'): 2, ('new', 'york'): 2, ('york', 'cnn'): 1, ('cnn', 'businessbitcoin'): 1, ('businessbitcoin', 'price'): 1, ('price', 'continued'): 1, ('continued', 'rebound'): 1, ('rebound', 'saturday'): 1, ('saturday', 'rising'): 1, ('rising', 'nearly'): 1, ('nearly', 'world'): 1, ('world', 'largest'): 1, ('largest', 'cryptocurrency'): 1, ('cryptocurrency', 'ha'): 1, ('ha', 'overshadowed'): 1, ('overshadowed', 'lately'): 1, ('lately', 'younger'): 1, ('younger', 'sibling'): 1, ('sibling', 'char'): 1, ('char', 'creator'): 1, ('creator', 'behind'): 1, ('behind', 'cryptopunks'): 1, ('cryptopunks', 'one'): 1, ('one', 'popular'): 1, ('popular', 'nft'): 1, ('nft', 'project'): 1, ('project', 'web'): 1, ('web', 'revealed'): 1, ('revealed', 'latest'): 1, ('latest', 'project'): 1, ('project', 'called'): 1, ('called', 'meebits'): 1, ('meebits', 'project'): 1, ('project', 'boast'): 1, ('boast', 'procedurally'): 1, ('procedurally', 'generated'): 1, ('generated', 'character'): 1, ('character', 'tha'): 1, ('tha', 'char'): 1, ('char', 'consensys'): 1, ('consensys', 'key'): 1, ('key', 'player'): 1, ('player', 'crypto'): 1, ('crypto', 'major'): 1, ('major', 'proponent'): 1, ('proponent', 'ethereum'): 1, ('ethereum', 'blockchain'): 1, ('blockchain', 'ha'): 1, ('ha', 'raised'): 1, ('raised', 'axa'): 1, ('axa', 'million'): 1, ('million', 'funding'): 1, ('funding', 'round'): 1, ('round', 'fromxajp'): 1, ('fromxajp', 'morgan'): 1, ('morgan', 'mastercard'): 1, ('mastercard', 'ubs'): 1, ('ubs', 'ag'): 1, ('ag', 'well'): 1, ('well', 'major'): 1, ('major', 'blockchain'): 1, ('blockchain', 'compan'): 1, ('compan', 'char'): 1, ('char', 'reuters'): 4, ('reuters', 'staffrnfile'): 2, ('staffrnfile', 'photo'): 2, ('photo', 'representation'): 2, ('representation', 'virtual'): 4, ('virtual', 'currency'): 4, ('currency', 'ethereum'): 4, ('ethereum', 'seen'): 4, ('seen', 'front'): 4, ('front', 'stock'): 4, ('stock', 'graph'): 4, ('graph', 'illustration'): 4, ('illustration', 'taken'): 4, ('taken', 'february'): 4, ('february', 'reutersdado'): 4, ('reutersdado', 'ruvicillustrationrnsingapore'): 2, ('ruvicillustrationrnsingapore', 'char'): 2, ('char', 'representation'): 2, ('reutersdado', 'ruvicillustrationcryptocurrency'): 2, ('ruvicillustrationcryptocurrency', 'ether'): 2, ('ether', 'hit'): 3, ('hit', 'record'): 3, ('record', 'high') ...

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
token_count(bitcoin_words, N=10)
# Out:
# [('char', 20),
#  ('ethereum', 10),
#  ('reuters', 7),
#  ('currency', 7),
#  ('cryptocurrency', 6),
#  ('stock', 6),
#  ('bitcoin', 5),
#  ('ha', 5),
#  ('project', 4),
#  ('major', 4)]

# %%
# Use token_count to get the top 10 words for Ethereum
token_count(ethereum_words, N=10)
# Out:
# [('char', 20),
#  ('ethereum', 10),
#  ('reuters', 7),
#  ('currency', 7),
#  ('cryptocurrency', 6),
#  ('stock', 6),
#  ('bitcoin', 5),
#  ('ha', 5),
#  ('project', 4),
#  ('major', 4)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
bitcoin_string = " ".join(bitcoin_words)
wc = WordCloud().generate(bitcoin_string)
plt.imshow(wc)

# %%
# Generate the Ethereum word cloud
ethereum_string = " ".join(ethereum_words)
wc = WordCloud().generate(ethereum_string)
plt.imshow(wc)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: en-core-web-sm==3.0.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.0.0/en_core_web_sm-3.0.0-py3-none-any.whl#egg=en_core_web_sm==3.0.0 in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (3.0.0)
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from en-core-web-sm==3.0.0) (3.0.6)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.7.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.8.2)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.20.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (20.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.0.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.24.0)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.5.2)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4; python_version < "3.8" in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.7.4.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.4 in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.5)
# Requirement already satisfied: setuptools in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (50.3.1.post20201107)
# Requirement already satisfied: thinc<8.1.0,>=8.0.3 in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (8.0.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.5)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.5)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.7.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (4.50.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.3 in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.4)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.3.2)
# Requirement already satisfied: jinja2 in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.11.2)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.7)
# Requirement already satisfied: six in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.10)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.2.1)
# Requirement already satisfied: zipp>=0.5; python_version < "3.8" in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from catalogue<2.1.0,>=2.0.3->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.4.0)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.1.1)
# Requirement already satisfied: boto3 in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from smart-open<4.0.0,>=2.2.0->pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.17.63)
# Requirement already satisfied: s3transfer<0.5.0,>=0.4.0 in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from boto3->smart-open<4.0.0,>=2.2.0->pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.4.2)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from boto3->smart-open<4.0.0,>=2.2.0->pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.10.0)
# Requirement already satisfied: botocore<1.21.0,>=1.20.63 in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from boto3->smart-open<4.0.0,>=2.2.0->pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.20.63)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\bwara\anaconda3\envs\pyvizenv\lib\site-packages (from botocore<1.21.0,>=1.20.63->boto3->smart-open<4.0.0,>=2.2.0->pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.8.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
bitcoin_concat = str(bitcoin_df['text'].tolist())
bitcoin_concat
# Out:
# '[\'Their investors call them disruptive innovators. Detractors like North Carolina Attorney General Josh Stein call them dirty scammers. But Leda Health co-founders Madison Campbell and Liesel Vaidya th… [+8679 chars]\', \'Cryptocurrency continues to gain mainstream acceptance, as PayPal announced that they have added Bitcoin, Ethereum, Bitcoin Cash, and Litecoin to its Venmo app. With a user base of 70 million, the mo… [+2782 chars]\', \'Venmo is jumping aboard the cryptocurrency bandwagon.\\xa0\\r\\nThe social payment service announced on Tuesday that its customers can now buy, hold, and sell cryptocurrencies within the Venmo app.\\xa0\\r\\nFour cr… [+1524 chars]\', "New York (CNN Business)Bitcoin prices continued their rebound Saturday, rising about 6% to nearly $58,000. But the world\'s largest cryptocurrency has been overshadowed lately by its younger sibling, … [+866 chars]", \'The creators behind CryptoPunks, one of the most popular NFT projects on the web, just revealed their latest project called Meebits. The project boasts 20,000 procedurally generated 3D characters tha… [+2000 chars]\', \'ConsenSys, a key player in crypto and a major proponent of the Ethereum blockchain, has raised a\\xa0$65 million funding round from\\xa0J.P. Morgan, Mastercard, and UBS AG, as well as major blockchain compan… [+8767 chars]\', \'By Reuters Staff\\r\\nFILE PHOTO: A representation of virtual currency Ethereum are seen in front of a stock graph in this illustration taken February 19, 2021. REUTERS/Dado Ruvic/Illustration\\r\\nSINGAPORE… [+748 chars]\', \'A representation of virtual currency Ethereum are seen in front of a stock graph in this illustration taken February 19, 2021. REUTERS/Dado Ruvic/IllustrationCryptocurrency ether hit a record high of… [+760 chars]\', \'It took a while to get here, but Dfinity is finally launching.\\xa0\\r\\nIn July 2018, I went to the Swiss city of Zug to speak to Dominic Williams, CEO of crypto platform Dfinity. Its blockchain project has… [+4319 chars]\', \'This story originally appeared on StockMarketUS Stock Futures Edge Higher On Monday Morning\\r\\nThe U.S. stock futures moved higher in pre-market trading on Monday as investors prepare themselves for th… [+6451 chars]\', \'This article was translated from our Spanish edition using AI technologies. Errors may exist due to this process.\\r\\nCryptocurrencies are the thing of today. Vitalik Buterin , 27-year-old co-founder of… [+831 chars]\', \'Non-fungible tokens (NFTs) are quickly becoming go-tos for digital collecting, and that now includes something you might have had as a kid: baseball cards. Topps is launching its first NFT-based base… [+1535 chars]\', \'Posted \\r\\nThe S&amp;P Dow Jones Indices launched new cryptocurrency indexes, further mainstreaming digital currencies including bitcoin and ethereum by bringing them to the trading floors of Wall Stre… [+30 chars]\', \'A representation of virtual currency Ethereum are seen in front of a stock graph in this illustration taken February 19, 2021. REUTERS/Dado Ruvic/IllustrationCryptocurrency ether extended gains to an… [+632 chars]\', \'By Reuters Staff\\r\\nSINGAPORE, May 3 (Reuters) - Cryptocurrency ether hit a record high on Monday to trade within a whisker of $3,000, extending last weeks rally in the wake of a report that the Europe… [+444 chars]\', \'By Reuters Staff\\r\\n(Adds detail of reported EIB plan and bitcoin price)\\r\\nSINGAPORE, May 3 (Reuters) - Cryptocurrency ether hit a record high on Monday to trade within a whisker of $3,000, extending la… [+684 chars]\', \'By Reuters Staff\\r\\nFILE PHOTO: A representation of virtual currency Ethereum are seen in front of a stock graph in this illustration taken February 19, 2021. REUTERS/Dado Ruvic/Illustration\\r\\nSINGAPORE… [+619 chars]\', \'Ethereum has outperformed major digital currency rivals this year, bolstered by the surge in decentralized finance (DeFi) and the anticipation of a technical adjustment this summer, but it faces  ...

# %%
# Run the NER processor on all of the text
bitcoin_doc = nlp(bitcoin_concat)

# Add a title to the document
bitcoin_doc.user_data["title"] = "Bitcoin spaCy Visualization"

# %%
# Render the visualization
displacy.render(bitcoin_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin spaCy Visualization</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">['Their investors call them disruptive innovators. Detractors like
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     North Carolina
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  Attorney General
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Josh Stein
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  call them dirty scammers. But Leda Health co-founders
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Madison Campbell
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Liesel Vaidya
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  th… [+8679 chars]', 'Cryptocurrency continues to gain mainstream acceptance, as
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PayPal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  announced that they have added
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin, Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin Cash
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Litecoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  to its
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Venmo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  app. With a user base of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     70 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# , the mo… [+2782 chars]', '
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Venmo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is jumping aboard the cryptocurrency bandwagon.\xa0\r\nThe social payment service announced on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  that its customers can now buy, hold, and sell cryptocurrencies within the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Venmo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  app.\xa0\r\nFour cr… [+1524 chars]', &quot;
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New York
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CNN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Business)Bitcoin prices continued their rebound
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Saturday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , rising
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about 6%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly $58,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# . But the world's largest cryptocurrency has been overshadowed lately by its younger sibling, … [+866 chars]&quot;, 'The creators behind
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CryptoPunks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the most popular
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  projects on the web, just revealed their latest project called
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Meebits
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# . The project boasts
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</sp

# %%
# List all Entities
for ent in bitcoin_doc.ents:
    print(ent.text, ent.label_)
# Out:
# North Carolina GPE
# Josh Stein PERSON
# Madison Campbell PERSON
# Liesel Vaidya PERSON
# PayPal ORG
# Bitcoin, Ethereum ORG
# Bitcoin Cash PERSON
# Litecoin PERSON
# Venmo PERSON
# 70 million CARDINAL
# Venmo PERSON
# Tuesday DATE
# Venmo PERSON
# New York GPE
# CNN ORG
# Saturday DATE
# about 6% PERCENT
# nearly $58,000 MONEY
# CryptoPunks ORG
# one CARDINAL
# NFT ORG
# Meebits PRODUCT
# 20,000 CARDINAL
# 3D ORG
# ConsenSys ORG
# Ethereum ORG
# Morgan GPE
# Mastercard PERSON
# UBS AG ORG
# Reuters ORG
# February 19, 2021 DATE
# Dado Ruvic PERSON
# February 19, 2021 DATE
# Dado Ruvic/IllustrationCryptocurrency PERSON
# Dfinity GPE
# July 2018 DATE
# Swiss NORP
# Dominic Williams PERSON
# StockMarketUS Stock Futures Edge Higher ORG
# Monday DATE
# U.S. GPE
# Monday DATE
# Spanish NORP
# AI ORG
# today DATE
# Vitalik Buterin PERSON
# 27-year-old DATE
# Topps GPE
# first ORDINAL
# NFT ORG
# Dow Jones Indices ORG
# February 19, 2021 DATE
# Dado Ruvic/IllustrationCryptocurrency PERSON
# Reuters ORG
# May 3 DATE
# Reuters ORG
# Monday DATE
# 3,000 MONEY
# last weeks DATE
# Europe LOC
# Reuters ORG
# May 3 DATE
# Reuters ORG
# Monday DATE
# 3,000 MONEY
# Reuters ORG
# February 19, 2021 DATE
# Dado Ruvic PERSON
# this year DATE
# this summer DATE
# Sotheby\ ORG
# Tuesday DATE
# Love WORK_OF_ART
# Air LAW
# first ORDINAL
# NEW YORK GPE
# May 7 DATE
# Reuters ORG
# this year DATE

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
ethereum_concat = str(ethereum_df['text'].tolist())
ethereum_concat
# Out:
# '[\'Their investors call them disruptive innovators. Detractors like North Carolina Attorney General Josh Stein call them dirty scammers. But Leda Health co-founders Madison Campbell and Liesel Vaidya th… [+8679 chars]\', \'Cryptocurrency continues to gain mainstream acceptance, as PayPal announced that they have added Bitcoin, Ethereum, Bitcoin Cash, and Litecoin to its Venmo app. With a user base of 70 million, the mo… [+2782 chars]\', \'Venmo is jumping aboard the cryptocurrency bandwagon.\\xa0\\r\\nThe social payment service announced on Tuesday that its customers can now buy, hold, and sell cryptocurrencies within the Venmo app.\\xa0\\r\\nFour cr… [+1524 chars]\', "New York (CNN Business)Bitcoin prices continued their rebound Saturday, rising about 6% to nearly $58,000. But the world\'s largest cryptocurrency has been overshadowed lately by its younger sibling, … [+866 chars]", \'The creators behind CryptoPunks, one of the most popular NFT projects on the web, just revealed their latest project called Meebits. The project boasts 20,000 procedurally generated 3D characters tha… [+2000 chars]\', \'ConsenSys, a key player in crypto and a major proponent of the Ethereum blockchain, has raised a\\xa0$65 million funding round from\\xa0J.P. Morgan, Mastercard, and UBS AG, as well as major blockchain compan… [+8767 chars]\', \'By Reuters Staff\\r\\nFILE PHOTO: A representation of virtual currency Ethereum are seen in front of a stock graph in this illustration taken February 19, 2021. REUTERS/Dado Ruvic/Illustration\\r\\nSINGAPORE… [+748 chars]\', \'A representation of virtual currency Ethereum are seen in front of a stock graph in this illustration taken February 19, 2021. REUTERS/Dado Ruvic/IllustrationCryptocurrency ether hit a record high of… [+760 chars]\', \'It took a while to get here, but Dfinity is finally launching.\\xa0\\r\\nIn July 2018, I went to the Swiss city of Zug to speak to Dominic Williams, CEO of crypto platform Dfinity. Its blockchain project has… [+4319 chars]\', \'This story originally appeared on StockMarketUS Stock Futures Edge Higher On Monday Morning\\r\\nThe U.S. stock futures moved higher in pre-market trading on Monday as investors prepare themselves for th… [+6451 chars]\', \'This article was translated from our Spanish edition using AI technologies. Errors may exist due to this process.\\r\\nCryptocurrencies are the thing of today. Vitalik Buterin , 27-year-old co-founder of… [+831 chars]\', \'Non-fungible tokens (NFTs) are quickly becoming go-tos for digital collecting, and that now includes something you might have had as a kid: baseball cards. Topps is launching its first NFT-based base… [+1535 chars]\', \'Posted \\r\\nThe S&amp;P Dow Jones Indices launched new cryptocurrency indexes, further mainstreaming digital currencies including bitcoin and ethereum by bringing them to the trading floors of Wall Stre… [+30 chars]\', \'A representation of virtual currency Ethereum are seen in front of a stock graph in this illustration taken February 19, 2021. REUTERS/Dado Ruvic/IllustrationCryptocurrency ether extended gains to an… [+632 chars]\', \'By Reuters Staff\\r\\nSINGAPORE, May 3 (Reuters) - Cryptocurrency ether hit a record high on Monday to trade within a whisker of $3,000, extending last weeks rally in the wake of a report that the Europe… [+444 chars]\', \'By Reuters Staff\\r\\n(Adds detail of reported EIB plan and bitcoin price)\\r\\nSINGAPORE, May 3 (Reuters) - Cryptocurrency ether hit a record high on Monday to trade within a whisker of $3,000, extending la… [+684 chars]\', \'By Reuters Staff\\r\\nFILE PHOTO: A representation of virtual currency Ethereum are seen in front of a stock graph in this illustration taken February 19, 2021. REUTERS/Dado Ruvic/Illustration\\r\\nSINGAPORE… [+619 chars]\', \'Ethereum has outperformed major digital currency rivals this year, bolstered by the surge in decentralized finance (DeFi) and the anticipation of a technical adjustment this summer, but it faces  ...

# %%
# Run the NER processor on all of the text
ethereum_doc = nlp(ethereum_concat)

# Add a title to the document
ethereum_doc.user_data["title"] = "Ethereum spaCy Visualization"

# %%
# Render the visualization
displacy.render(ethereum_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum spaCy Visualization</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">['Their investors call them disruptive innovators. Detractors like
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     North Carolina
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  Attorney General
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Josh Stein
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  call them dirty scammers. But Leda Health co-founders
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Madison Campbell
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Liesel Vaidya
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  th… [+8679 chars]', 'Cryptocurrency continues to gain mainstream acceptance, as
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PayPal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  announced that they have added
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin, Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin Cash
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Litecoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  to its
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Venmo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  app. With a user base of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     70 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# , the mo… [+2782 chars]', '
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Venmo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is jumping aboard the cryptocurrency bandwagon.\xa0\r\nThe social payment service announced on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  that its customers can now buy, hold, and sell cryptocurrencies within the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Venmo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  app.\xa0\r\nFour cr… [+1524 chars]', &quot;
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New York
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CNN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Business)Bitcoin prices continued their rebound
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Saturday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , rising
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about 6%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly $58,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# . But the world's largest cryptocurrency has been overshadowed lately by its younger sibling, … [+866 chars]&quot;, 'The creators behind
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CryptoPunks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the most popular
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  projects on the web, just revealed their latest project called
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Meebits
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# . The project boasts
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</s

# %%
# List all Entities
for ent in ethereum_doc.ents:
    print(ent.text, ent.label_)
# Out:
# North Carolina GPE
# Josh Stein PERSON
# Madison Campbell PERSON
# Liesel Vaidya PERSON
# PayPal ORG
# Bitcoin, Ethereum ORG
# Bitcoin Cash PERSON
# Litecoin PERSON
# Venmo PERSON
# 70 million CARDINAL
# Venmo PERSON
# Tuesday DATE
# Venmo PERSON
# New York GPE
# CNN ORG
# Saturday DATE
# about 6% PERCENT
# nearly $58,000 MONEY
# CryptoPunks ORG
# one CARDINAL
# NFT ORG
# Meebits PRODUCT
# 20,000 CARDINAL
# 3D ORG
# ConsenSys ORG
# Ethereum ORG
# Morgan GPE
# Mastercard PERSON
# UBS AG ORG
# Reuters ORG
# February 19, 2021 DATE
# Dado Ruvic PERSON
# February 19, 2021 DATE
# Dado Ruvic/IllustrationCryptocurrency PERSON
# Dfinity GPE
# July 2018 DATE
# Swiss NORP
# Dominic Williams PERSON
# StockMarketUS Stock Futures Edge Higher ORG
# Monday DATE
# U.S. GPE
# Monday DATE
# Spanish NORP
# AI ORG
# today DATE
# Vitalik Buterin PERSON
# 27-year-old DATE
# Topps GPE
# first ORDINAL
# NFT ORG
# Dow Jones Indices ORG
# February 19, 2021 DATE
# Dado Ruvic/IllustrationCryptocurrency PERSON
# Reuters ORG
# May 3 DATE
# Reuters ORG
# Monday DATE
# 3,000 MONEY
# last weeks DATE
# Europe LOC
# Reuters ORG
# May 3 DATE
# Reuters ORG
# Monday DATE
# 3,000 MONEY
# Reuters ORG
# February 19, 2021 DATE
# Dado Ruvic PERSON
# this year DATE
# this summer DATE
# Sotheby\ ORG
# Tuesday DATE
# Love WORK_OF_ART
# Air LAW
# first ORDINAL
# NEW YORK GPE
# May 7 DATE
# Reuters ORG
# this year DATE

# %% [markdown]
# ---
